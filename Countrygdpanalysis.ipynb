# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\rohit\OneDrive\Downloads\data.csv")

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.sort_values('InternetUsers')
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 52       Eritrea         ERI     34.800         0.9000           Low income
# 172  Timor-Leste         TLS     35.755         1.1000  Lower middle income
# 11       Burundi         BDI     44.151         1.3000           Low income
# 156      Somalia         SOM     43.891         1.5000           Low income
# 117      Myanmar         MMR     18.119         1.6000  Lower middle income
# ..           ...         ...        ...            ...                  ...
# 47       Denmark         DNK     10.000        94.6297          High income
# 163       Sweden         SWE     11.800        94.7836          High income
# 131       Norway         NOR     11.600        95.0534          High income
# 22       Bermuda         BMU     10.400        95.3000          High income
# 84       Iceland         ISL     13.400        96.5468          High income
#
# [195 rows x 5 columns]

# %%
df.sort_values('BirthRate',ascending = True)

#ascending order via birthrate
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 74   Hong Kong SAR, China         HKG      7.900        74.2000
# 142              Portugal         PRT      7.900        62.0956
# 89                  Japan         JPN      8.200        89.7100
# 45                Germany         DEU      8.500        84.1700
# 68                 Greece         GRC      8.500        59.8663
# ..                    ...         ...        ...            ...
# 115                  Mali         MLI     44.138         3.5000
# 11                Burundi         BDI     44.151         1.3000
# 167                  Chad         TCD     45.745         2.3000
# 2                  Angola         AGO     45.985        19.1000
# 127                 Niger         NER     49.661         1.7000
#
#              IncomeGroup
# 74           High income
# 142          High income
# 89           High income
# 45           High income
# 68           High income
# ..                   ...
# ...

# %%
df.sort_values('CountryName',ascending = False)

#descending order in country name via alphabetical
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 194               Zimbabwe         ZWE     35.715           18.5
# 193                 Zambia         ZMB     40.471           15.4
# 190            Yemen, Rep.         YEM     32.947           20.0
# 188     West Bank and Gaza         PSE     30.394           46.6
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# ..                     ...         ...        ...            ...
# 7      Antigua and Barbuda         ATG     16.447           63.4
# 2                   Angola         AGO     45.985           19.1
# 49                 Algeria         DZA     24.738           16.5
# 3                  Albania         ALB     12.877           57.2
# 1              Afghanistan         AFG     35.253            5.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 190  Lower middle income
# 188  Lower middle income
# 185          High income
# ..                   ...
# ...

# %%
df.head(5)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df.tail(5)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.tail(20)
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 175                         Tunisia         TUN     19.800          43.80
# 176                          Turkey         TUR     16.836          46.25
# 177                        Tanzania         TZA     39.518           4.40
# 178                          Uganda         UGA     43.474          16.20
# 179                         Ukraine         UKR     11.100          41.00
# 180                         Uruguay         URY     14.374          57.69
# 181                   United States         USA     12.500          84.20
# 182                      Uzbekistan         UZB     22.500          38.20
# 183  St. Vincent and the Grenadines         VCT     16.306          52.00
# 184                   Venezuela, RB         VEN     19.842          54.90
# 185           Virgin Islands (U.S.)         VIR     10.700          45.30
# 186                         Vietnam         VNM     15.537          43.90
# ...

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[::-2]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 190           Yemen, Rep.         YEM     32.947           20.0
# 188    West Bank and Gaza         PSE     30.394           46.6
# 186               Vietnam         VNM     15.537           43.9
# ..                    ...         ...        ...            ...
# 8               Australia         AUS     13.200           83.0
# 6                 Armenia         ARM     13.308           41.9
# 4    United Arab Emirates         ARE     11.044           88.0
# 2                  Angola         AGO     45.985           19.1
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 192           Low income
# 190  Lower middle income
# 188  Lower middle income
# 186  Lower middle income
# ..                   ...
# ...

# %%
df[1:100:10]
# Out:
#          CountryName CountryCode  BirthRate  InternetUsers  \
# 1        Afghanistan         AFG     35.253         5.9000
# 11           Burundi         BDI     44.151         1.3000
# 21            Belize         BLZ     23.092        33.6000
# 31       Switzerland         CHE     10.200        86.3400
# 41              Cuba         CUB     10.400        27.9300
# 51  Egypt, Arab Rep.         EGY     28.032        29.4000
# 61    United Kingdom         GBR     12.200        89.8441
# 71         Guatemala         GTM     27.465        19.7000
# 81           Ireland         IRL     15.000        78.2477
# 91             Kenya         KEN     35.194        39.0000
#
#             IncomeGroup
# 1            Low income
# 11           Low income
# 21  Upper middle income
# 31          High income
# 41  Upper middle income
# 51  Lower middle income
# 61          High income
# 71  Lower middle income
# 81          High income
# 91  Lower middle income

# %%
df[1:10:2]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 1          Afghanistan         AFG     35.253         5.9000
# 3              Albania         ALB     12.877        57.2000
# 5            Argentina         ARG     17.716        59.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 1           Low income
# 3  Upper middle income
# 5          High income
# 7          High income
# 9          High income

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.tail(1)
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 194    Zimbabwe         ZWE     35.715           18.5  Low income

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
dfcategory = df[['CountryName','CountryCode','IncomeGroup']]

# %%
dfcategory
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
len(dfcategory)
# Out:
# 195

# %%
dfcategory.size
# Out:
# 585

# %%
dfcategory.shape
# Out:
# (195, 3)

# %%
dfcategory.ndim
# Out:
# 2

# %%
dfcategory.dtypes
# Out:
# CountryName    object
# CountryCode    object
# IncomeGroup    object
# dtype: object

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(dfcategory.columns)
# Out:
# 3

# %%
len(df.columns)
# Out:
# 5

# %%
dfcategory.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
dfcategory.info
# Out:
# <bound method DataFrame.info of               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]>

# %%
df_num = df[['BirthRate','InternetUsers']]

# %%
df_num
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
len(df_num)
# Out:
# 195

# %%
type(df_num)
# Out:
# pandas.core.frame.DataFrame

# %%
df_num.size
# Out:
# 390

# %%
df_num.shape
# Out:
# (195, 2)

# %%
df_num.ndim
# Out:
# 2

# %%
df_num.value_counts()
# Out:
# BirthRate  InternetUsers
# 7.900      62.0956          1
#            74.2000          1
# 8.200      89.7100          1
# 8.500      58.4593          1
#            59.8663          1
#                            ..
# 44.138     3.5000           1
# 44.151     1.3000           1
# 45.745     2.3000           1
# 45.985     19.1000          1
# 49.661     1.7000           1
# Name: count, Length: 195, dtype: int64

# %%
df_num.mean()
# Out:
# BirthRate        21.469928
# InternetUsers    42.076471
# dtype: float64

# %%
df[4:8]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
df[2:7]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            IncomeGroup
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
df[10:12]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10  Azerbaijan         AZE     18.300           58.7  Upper middle income
# 11     Burundi         BDI     44.151            1.3           Low income

# %%
df[45:87]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 45                Germany         DEU      8.500      84.170000
# 46               Djibouti         DJI     25.486       9.500000
# 47                Denmark         DNK     10.000      94.629700
# 48     Dominican Republic         DOM     21.198      45.900000
# 49                Algeria         DZA     24.738      16.500000
# 50                Ecuador         ECU     21.070      40.353684
# 51       Egypt, Arab Rep.         EGY     28.032      29.400000
# 52                Eritrea         ERI     34.800       0.900000
# 53                  Spain         ESP      9.100      71.635000
# 54                Estonia         EST     10.300      79.400000
# 55               Ethiopia         ETH     32.925       1.900000
# 56                Finland         FIN     10.700      91.514400
# 57                   Fiji         FJI     20.463      37.100000
# 58                 France         FRA     12.300      81.919800
# ...

# %%
a = df[45:87]

# %%
a
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 45                Germany         DEU      8.500      84.170000
# 46               Djibouti         DJI     25.486       9.500000
# 47                Denmark         DNK     10.000      94.629700
# 48     Dominican Republic         DOM     21.198      45.900000
# 49                Algeria         DZA     24.738      16.500000
# 50                Ecuador         ECU     21.070      40.353684
# 51       Egypt, Arab Rep.         EGY     28.032      29.400000
# 52                Eritrea         ERI     34.800       0.900000
# 53                  Spain         ESP      9.100      71.635000
# 54                Estonia         EST     10.300      79.400000
# 55               Ethiopia         ETH     32.925       1.900000
# 56                Finland         FIN     10.700      91.514400
# 57                   Fiji         FJI     20.463      37.100000
# 58                 France         FRA     12.300      81.919800
# ...

# %%
a.size
# Out:
# 210

# %%
a.shape
# Out:
# (42, 5)

# %%
a.ndim
# Out:
# 2

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
len(a)
# Out:
# 42

# %%
a.sort_values(by = 'InternetUsers', ascending = False)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 84                Iceland         ISL     13.400      96.546800
# 47                Denmark         DNK     10.000      94.629700
# 56                Finland         FIN     10.700      91.514400
# 61         United Kingdom         GBR     12.200      89.844100
# 45                Germany         DEU      8.500      84.170000
# 58                 France         FRA     12.300      81.919800
# 54                Estonia         EST     10.300      79.400000
# 81                Ireland         IRL     15.000      78.247700
# 74   Hong Kong SAR, China         HKG      7.900      74.200000
# 78                Hungary         HUN      9.200      72.643900
# 53                  Spain         ESP      9.100      71.635000
# 85                 Israel         ISR     21.300      70.800000
# 76                Croatia         HRV      9.400      66.747600
# 70              Greenland         GRL     14.500      65.800000
# ...

# %%
df['BirthRate'] * df['InternetUsers']
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
a.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
a.head()
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 45             Germany         DEU      8.500        84.1700
# 46            Djibouti         DJI     25.486         9.5000
# 47             Denmark         DNK     10.000        94.6297
# 48  Dominican Republic         DOM     21.198        45.9000
# 49             Algeria         DZA     24.738        16.5000
#
#             IncomeGroup
# 45          High income
# 46  Lower middle income
# 47          High income
# 48  Upper middle income
# 49  Upper middle income

# %%
a.tail()
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 82  Iran, Islamic Rep.         IRN     17.900        29.9500
# 83                Iraq         IRQ     31.093         9.2000
# 84             Iceland         ISL     13.400        96.5468
# 85              Israel         ISR     21.300        70.8000
# 86               Italy         ITA      8.500        58.4593
#
#             IncomeGroup
# 82  Upper middle income
# 83  Upper middle income
# 84          High income
# 85          High income
# 86          High income

# %%
a.head(27)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 45                Germany         DEU      8.500      84.170000
# 46               Djibouti         DJI     25.486       9.500000
# 47                Denmark         DNK     10.000      94.629700
# 48     Dominican Republic         DOM     21.198      45.900000
# 49                Algeria         DZA     24.738      16.500000
# 50                Ecuador         ECU     21.070      40.353684
# 51       Egypt, Arab Rep.         EGY     28.032      29.400000
# 52                Eritrea         ERI     34.800       0.900000
# 53                  Spain         ESP      9.100      71.635000
# 54                Estonia         EST     10.300      79.400000
# 55               Ethiopia         ETH     32.925       1.900000
# 56                Finland         FIN     10.700      91.514400
# 57                   Fiji         FJI     20.463      37.100000
# 58                 France         FRA     12.300      81.919800
# ...

# %%
a.tail(22)
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 65           Gambia, The         GMB     42.525        14.0000
# 66         Guinea-Bissau         GNB     37.503         3.1000
# 67     Equatorial Guinea         GNQ     35.362        16.4000
# 68                Greece         GRC      8.500        59.8663
# 69               Grenada         GRD     19.334        35.0000
# 70             Greenland         GRL     14.500        65.8000
# 71             Guatemala         GTM     27.465        19.7000
# 72                  Guam         GUM     17.389        65.4000
# 73                Guyana         GUY     18.885        35.0000
# 74  Hong Kong SAR, China         HKG      7.900        74.2000
# 75              Honduras         HND     21.593        17.8000
# 76               Croatia         HRV      9.400        66.7476
# 77                 Haiti         HTI     25.345        10.6000
# 78               Hungary         HUN      9.200        72.6439
# ...

# %%
df['product of birth rate and internet users'] = df['BirthRate'] * df['InternetUsers']

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  product of birth rate and internet users
# 0            High income                                  808.2516
# ...

# %%
len(df)
# Out:
# 195

# %%
len(df.columns)
# Out:
# 6

# %%
b = df.columns

# %%
len(b)
# Out:
# 6

# %%
Internetusersgreaterthan5 = df[df.InternetUsers<5]

# %%
Internetusersgreaterthan5
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 13                      Benin         BEN     36.440            4.9
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 117                   Myanmar         MMR     18.119            1.6
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# ...

# %%
birthratemorethan40 = df[df.BirthRate>40]

# %%
birthratemorethan40
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup  product of birth rate and internet users
# 2    Upper middle income                                  878.3135
# ...

# %%
len(birthratemorethan40)
# Out:
# 12

# %%
len(Internetusersgreaterthan5)
# Out:
# 19

# %%
df.IncomeGroup.nunique()
# Out:
# 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = 5,2  #here we are width size is 6, breadth = 2

# %%
vis1 = sns.distplot(df['InternetUsers'])

# %%
vis1 = sns.distplot(df['BirthRate'])

# %%
vis2 = sns.boxplot(data = df, x = 'IncomeGroup', y = 'BirthRate')
